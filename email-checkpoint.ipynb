# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('result.xlsx')

# %%
df.head()
# Out:
#                                             profileUrl         fullName  \
# 0            https://www.linkedin.com/in/sidharth-jain    Sidharth Jain
# 1             https://www.linkedin.com/in/thedeviloper  Hitesh Pariyani
# 2               https://www.linkedin.com/in/raj-tejani       Raj Tejani
# 3  https://www.linkedin.com/in/dashrath-singh-74474147   Dashrath Singh
# 4       https://www.linkedin.com/in/theonlybhavinengle     Bhavin Engle
#
#   firstName  lastName  \
# 0  Sidharth      Jain
# 1    Hitesh  Pariyani
# 2       Raj    Tejani
# 3  Dashrath     Singh
# 4    Bhavin     Engle
#
#                                                                                                                                                                profileImageUrl  \
# 0  https://media.licdn.com/dms/image/C4E03AQGTVjaDVbqtAw/profile-displayphoto-shrink_100_100/0/1603513893182?e=1695254400&v=beta&t=e5d2gxKA5pg-AYdAluCnNjW5U0BAWLWeb-_kAsBv55c
# ...

# %%
df = df.drop(['profileImageUrl','additionalInfo','connectionDegree','sharedConnections','url','name','query','category','timestamp','currentJob','error','summary'], axis =1)

# %%
df.head()
# Out:
#                                             profileUrl         fullName  \
# 0            https://www.linkedin.com/in/sidharth-jain    Sidharth Jain
# 1             https://www.linkedin.com/in/thedeviloper  Hitesh Pariyani
# 2               https://www.linkedin.com/in/raj-tejani       Raj Tejani
# 3  https://www.linkedin.com/in/dashrath-singh-74474147   Dashrath Singh
# 4       https://www.linkedin.com/in/theonlybhavinengle     Bhavin Engle
#
#   firstName  lastName  \
# 0  Sidharth      Jain
# 1    Hitesh  Pariyani
# 2       Raj    Tejani
# 3  Dashrath     Singh
# 4    Bhavin     Engle
#
#                                                                                                                                                                    job  \
# 0  CEO - GraffersID | Offshore Development Center | Trusted by startups in YC | Techstars | Harvard | Google | Coca-Cola | Hire Remote Developers on Contract in 1 day
# ...

# %%
df = df.rename(columns = {'firstName':'fn','lastName':'ln'})

# %% [markdown]
# #

# %%
df4 = df.iloc[:,[0,2,3]]

# %%
df4
# Out:
#                                                     profileUrl          fn  \
# 0                    https://www.linkedin.com/in/sidharth-jain    Sidharth
# 1                     https://www.linkedin.com/in/thedeviloper      Hitesh
# 2                       https://www.linkedin.com/in/raj-tejani         Raj
# 3          https://www.linkedin.com/in/dashrath-singh-74474147    Dashrath
# 4               https://www.linkedin.com/in/theonlybhavinengle      Bhavin
# ..                                                         ...         ...
# 447  https://www.linkedin.com/in/achintya-chatterjee-7ba2b611a    Achintya
# 448                 https://www.linkedin.com/in/krishsudhanshu       Krish
# 449        https://www.linkedin.com/in/devesh-maurya-975209251      Devesh
# 450        https://www.linkedin.com/in/padmini-suresh-681ab8b5     Padmini
# 451                      https://www.linkedin.com/in/siddhiman  Siddhartha
#
#              ln
# 0          Jain
# 1      Pariyani
# ...

# %%
# Save the new dataset to an Excel file
df4.to_excel('df4.xlsx', index=False)

# %%
df4
# Out:
#                                                     profileUrl          fn  \
# 0                    https://www.linkedin.com/in/sidharth-jain    Sidharth
# 1                     https://www.linkedin.com/in/thedeviloper      Hitesh
# 2                       https://www.linkedin.com/in/raj-tejani         Raj
# 3          https://www.linkedin.com/in/dashrath-singh-74474147    Dashrath
# 4               https://www.linkedin.com/in/theonlybhavinengle      Bhavin
# ..                                                         ...         ...
# 447  https://www.linkedin.com/in/achintya-chatterjee-7ba2b611a    Achintya
# 448                 https://www.linkedin.com/in/krishsudhanshu       Krish
# 449        https://www.linkedin.com/in/devesh-maurya-975209251      Devesh
# 450        https://www.linkedin.com/in/padmini-suresh-681ab8b5     Padmini
# 451                      https://www.linkedin.com/in/siddhiman  Siddhartha
#
#              ln
# 0          Jain
# 1      Pariyani
# ...

# %%
df2 = pd.read_excel('df4.xlsx')
first_names = df2['fn'].tolist()
last_names = df2['ln'].tolist()
email_list = []

# Loop through the names and generate email addresses
for i in range(len(first_names)):
    first_name = first_names[i]
    last_name = last_names[i]
    for domain in ['gmail.com']:
        email = [
                 f"{str(last_name).lower()}-{str(first_name).lower()}@{domain}",
                 f"{str(last_name).lower()}-{str(first_name)[0].lower()}@{domain}",
                 f"{str(last_name)[0].lower()}-{str(first_name).lower()}@{domain}",
                 f"{str(last_name)[0].lower()}-{str(first_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}-{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}--{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}_{str(last_name).lower()}@{domain}",
                 f"{str(first_name)[0].lower()}_{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}_{str(last_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}_{str(last_name)[0].lower()}@{domain}",
                 f"{str(last_name).lower()}_{str(first_name).lower()}@{domain}",
                 f"{str(last_name).lower()}_{str(first_name)[0].lower()}@{domain}",
                 f"{str(last_name)[0].lower()}_{str(first_name).lower()}@{domain}",
                 f"{str(last_name)[0].lower()}_{str(first_name)[0].lower()}@{domain}",
                 f"{str(first_name).lower()}__{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}@{domain}",
                 f"{str(first_name)[0].lower()}{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}.{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}{str(last_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}.{str(last_name).lower()}@{domain}", 
                 f"{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}.{str(last_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}{str(last_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}.{str(last_name)[0].lower()}@{domain}",
                 f"{str(last_name).lower()}{str(first_name).lower()}@{domain}",
                 f"{str(last_name).lower()}{str(first_name)[0].lower()}@{domain}",
                 f"{str(last_name).lower()}.{str(first_name)[0].lower()}@{domain}",
                 f"{str(last_name)[0].lower()}.{str(first_name).lower()}@{domain}",
                 f"{str(last_name)[0].lower()}{str(first_name).lower()}@{domain}",
                 f"{str(last_name)[0].lower()}{str(first_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}.{str(last_name).lower()}@{domain}",
                 f"{str(first_name)[0].lower()}{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}..{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}-{str(last_name).lower()}@{domain}",
                 f"{str(first_name)[0].lower()}-{str(last_name).lower()}@{domain}",
                 f"{str(first_name).lower()}-{str(last_name)[0].lower()}@{domain}",
                 f"{str(first_name)[0].lower()}-{str(last_name)[0].lower()}@{domain}",
                ]
        
        email_list.append(email)

# Create a DataFrame using the lists
df = pd.DataFrame({"firstname": first_names, "lastname": last_names, "Gmail": email_list})

# Save the DataFrame to an Excel file
df.to_excel("mail22.xlsx", index=False)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
pd.read_excel("mail22.xlsx")
# Out:
#       firstname    lastname  \
# 0      Sidharth        Jain
# 1        Hitesh    Pariyani
# 2           Raj      Tejani
# 3      Dashrath       Singh
# 4        Bhavin       Engle
# ..          ...         ...
# 447    Achintya  Chatterjee
# 448       Krish   Sudhanshu
# 449      Devesh      Maurya
# 450     Padmini      Suresh
# 451  Siddhartha      Dhiman
#
# ...
